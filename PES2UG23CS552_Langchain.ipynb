# %% [markdown]
# Shravani Isukapalli
# PES2UG23CS552

# %% [markdown]
# LangChain

# %%
# %pip install langchain langchain-google-genai python-dotenv

import os
import getpass

# Enter Gemini API key
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

response = llm.invoke("Hello, what is AI?")
print(response.content)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.2 MB/s eta 0:00:00
# ...
# Enter Gemini API Key: ··········
# AI stands for **Artificial Intelligence**.
#
# At its core, AI is a broad field of computer science focused on creating machines that can **perform tasks that typically require human intelligence**.
#
# Think of it as teaching computers to "think" and "learn" in ways similar to how humans do.
#
# Here's a breakdown of what that means:
#
# 1.  **Simulating Human Cognitive Functions:** AI aims to replicate abilities like:
#     *   **Learning:** Acquiring information and rules for using it.
#     *   **Reasoning:** Using rules to reach approximate or definite conclusions.
#     *   **Problem-solving:** Finding solutions to complex challenges.
#     *   **Perception:** Interpreting sensory input (like images, sounds, text).
#     *   **Language Understanding:** Comprehending and generating human language.
#     *   **Decision-making:** Choosing the best course of action.
#
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_focused=ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)

llm_creative=ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)

# %%
prompt="define word 'idea' in one sentence"

print(" ---FOCUSED (Temp=0)---")
print(f"Run 1: {llm_focused.invoke(prompt).content}")
print(f"Run 2: {llm_focused.invoke(prompt).content}")
# Out:
#  ---FOCUSED (Temp=0)---
# Run 1: An idea is a thought, concept, or plan that originates in the mind.
# Run 2: An idea is a thought, concept, or plan that originates in the mind.

# %%
prompt="define word 'idea' in one sentence"

print(" ---FOCUSED (Temp=1)---")
print(f"Run 1: {llm_focused.invoke(prompt).content}")
print(f"Run 2: {llm_focused.invoke(prompt).content}")
# Out:
#  ---FOCUSED (Temp=1)---
# Run 1: An idea is a thought, concept, or plan that originates in the mind.
# Run 2: An idea is a thought, concept, or plan that originates in the mind.

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"]= getpass.getpass("enter your google api key: ")

llm= ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages =[
    SystemMessage(content="you are a good student who always answers correctly "),
    HumanMessage(content="What is the capital of Fraance?")
    ]
response = llm.invoke(messages)
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"]=getpass.getpass("enter google api key ")

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template=ChatPromptTemplate.from_template("tell me a joke about {topic}")
parser=StrOutputParser()

# %%
prompt_value=template.invoke({"topic": "crows"})

response_obj=llm.invoke(prompt_value)

final_text=parser.invoke(response_obj)

print(final_text)
# Out:
# Why did the crow sit on the phone pole?
# ... To make a **caw-ll**!

# %%
chain=template | llm | parser
print(chain.invoke({"topic": "Octopuses"}))
# Out:
# Why did the octopus get kicked out of the poker game?
#
# Because it kept holding too many hands!

# %% [markdown]
# Assignment

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

template_movie = ChatPromptTemplate.from_template(
    "When was the movie '{movie}' released and calculate how many years ago that was from 2026. Answer in one sentence"
)

# %%
parser = StrOutputParser()

# %%
movie_chain = template_movie | llm | parser

# %%
print(movie_chain.invoke({"movie": "Taare Zameen Par"}))
# Out:
# The movie 'Taare Zameen Par' was released in 2007, which was 19 years ago from 2026.
